# %% [markdown]
# # Detecting promising neighborhoods for the next boba storefront

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data that we need](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem  <a name='introduction'></a>

# %% [markdown]
# Toronto has witnessed the rapid growth of boba market in recent years. The competition among bubble tea brands is still in process. This project is to detect promising neighborhoods in Toronto to start the next boba storefront. It is clear that the target audience of the project are bubble tea sellers like giant boba brands like Coco, Chatime and Gong Cha, whose target cunsumers are young people.
#
# __In this project,places not already crowed with bubble tea cafe and near universities or colleges are considered to be otptimal locations.__
#
# After generating a number of prospective neighborhoods, we will have a closer look to these neighborhoods and analyze their advantages and disadvantages, in order to help decision makers to find the best possible site.

# %% [markdown]
# ## Data that we need <a name='data'></a>

# %% [markdown]
# 1. number of existing boba storefronts in the neighborhood
# 2. number of universities and colleges, if any
#
# Following data sources will be needed to extract/generate the required information:
# * names of Toronto neighborhoods will be obtained from **Wikipedia**
# * coordinate of neighborhoods will be obtained from **cousera** in case of the disconnection of **geocoder**
# * number of existing boba storefronts will be obtained using **Foursquare API**
# * number of universities and colleges and their location in every neighborhood will be obtained using **Foursquare API**
# * number of shopping places and their location in every neighborhood will be obtained using **Foursquare API**

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import string
import requests
import geocoder
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium
from sklearn.cluster import KMeans
import csv

# %% [markdown]
# ### Names and Coordinare of Neighborhoods

# %% [markdown]
# #### The geographical scope is Toronto, so I continue to use the geographical neighbourhoods data I got last week, below is a link to the jupyter notebook with related code
# [applied_data_science_capstone.ipynb](https://github.com/JiaqiChen0119/coursera-IBM-capstone/blob/master/applied_data_science_capstone.ipynb)

# %%
toronto_data = pd.read_csv('toronto_data.csv')

# %%
toronto_data.head()
# Out:
#   PostalCode      Borough                         Neighbourhood   Latitude  \
# 0        M1B  Scarborough                         Rouge,Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2        M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3        M1G  Scarborough                                Woburn  43.770992
# 4        M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# #### Let's crete a map showing _distribution of neighborhoods_.The coordinate of Toronto is from wikipedia.

# %%
#geographical coordinates of Toronto
latitude = 43.653226
longitude = -79.383184

# %%
#visulize neighborhoods in Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
# add markers to map
for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# With coordinate of each neighborhood, let's use Foursquare API to get info on __bubble tea shops, schools, and shopping malls or shopping plazea__ in each neighborhood.The exploring radius of each neighborhood is set to be 1km.

# %%
CLIENT_ID = '*********' # your Foursquare ID
CLIENT_SECRET = '**********' # your Foursquare Secret
VERSION = '20180605'

Bubble_Tea_Shop = '52e81612bcbc57f1066b7a0c'#Category No of bubble tea shops
College_University = '4d4b7105d754a06372d81259'#Category No of colleges and universities
Shopping_Plaza = '5744ccdfe4b0c0459246b4dc' #Category No of shopping plazas
Shopping_Mall = '4bf58dd8d48988d1fd941735'#Category No of shopping malls

def getNearbyvenues(names,latitudes,longitudes,category,radius = 1000,LIMIT = 100):
    venues_list = []
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(
                CLIENT_ID,
                CLIENT_SECRET,
                lat,
                lng,
                VERSION,
                category,
                radius,
                LIMIT)
        try:
            results = requests.get(url).json()['response']['groups'][0]['items']
            venues_list.append([(name,
                               lat,
                               lng,
                               v['venue']['name'],
                               v['venue']['location']['lat'],
                               v['venue']['location']['lng']) for v in results])
        except:
            pass
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood',
                             'Neighbourhood Latitude',
                             'Neighbourhood Longitude',
                             'Venue',
                             'Venue Latitude',
                             'Venue Longitude']

    return(nearby_venues)

# %%
nearbybobashop = getNearbyvenues(toronto_data['Neighbourhood'],
                                  toronto_data['Latitude'],
                                  toronto_data['Longitude'],Bubble_Tea_Shop,radius = 1000,LIMIT = 100)

# %%
nearbybobashop.head()
# Out:
#                                        Neighbourhood  Neighbourhood Latitude  \
# 0                                   Maryvale,Wexford               43.750071
# 1                                          Agincourt               43.794200
# 2                                          Agincourt               43.794200
# 3  Agincourt North,L'Amoreaux East,Milliken,Steel...               43.815252
# 4  Agincourt North,L'Amoreaux East,Milliken,Steel...               43.815252
#
#    Neighbourhood Longitude                       Venue  Venue Latitude  \
# 0               -79.295849                   Pho Metro       43.745365
# 1               -79.262029           Health Oolong Tea       43.789042
# 2               -79.262029  Real Fruit Bubble Tea 真果茶坊       43.797208
# 3               -79.284577                  Go For Tea       43.814701
# 4               -79.284577          OneZo Tapioca 丸作食茶       43.815838
#
#    Venue Longitude
# 0       -79.294462
# 1       -79.268513
# 2       -79.271523
# 3       -79.292643
# 4       -79.293655

# %%
nearbyCollege_University = getNearbyvenues(toronto_data['Neighbourhood'],
                                  toronto_data['Latitude'],
                                  toronto_data['Longitude'],College_University,radius = 1000,LIMIT = 100)

# %%
nearbyCollege_University.head()
# Out:
#                           Neighbourhood  Neighbourhood Latitude  \
# 0                         Rouge,Malvern               43.806686
# 1  Highland Creek,Rouge Hill,Port Union               43.784535
# 2  Highland Creek,Rouge Hill,Port Union               43.784535
# 3       Guildwood,Morningside,West Hill               43.763573
# 4       Guildwood,Morningside,West Hill               43.763573
#
#    Neighbourhood Longitude                                    Venue  \
# 0               -79.194353                        Evergreen College
# 1               -79.160497                      UTSC - Physics Labs
# 2               -79.160497               st brendan catholic school
# 3               -79.188711                               Z Cups Etc
# 4               -79.188711  Boys and Girls Club of East Scarborough
#
#    Venue Latitude  Venue Longitude
# 0       43.802162       -79.199654
# 1       43.780079       -79.156193
# 2       43.783052       -79.149267
# 3       43.767973       -79.188123
# 4       43.757549       -79.193691

# %% [markdown]
# We're interested in schools because there are young people who are probably partial to sweeet bubble tea, but students are more likely to stay at school, college, office, institute and university, instead of other places like laboratories. So we will only consider venues that have any word from __'school', 'college', 'office', 'institute' and 'university'__.

# %%
uni_words = ['school', 'college', 'office', 'institute','university']
uni_venues = []
for venue in nearbyCollege_University['Venue']:
    words=venue.lower()
    for uni_word in uni_words:
        if uni_word in words:
            print(words)
            uni_venues.append(venue)
# Out:
# evergreen college
# st brendan catholic school
# st. richard catholic school
# oxford college
# uwin pro o/a the canadian college for higher studies
# cedarbrook jr public school
# salaheddin islamic school
# computek college
# everest college - scarborough
# institute of technical trades
# brown's schoolhouse
# cdi college scarborough
# bond academy private school
# medix college
# trios college ica
# trios college pta/ota
# trios college career services
# trios college scarborough
# trios college book room
# stephen leacock collegiate institute
# success tutorial school
# cliffwood public school
# canadian memorial chiropractic college
# william lyon mackenzie collegiate institute
# master's college & seminary
# umc high school
# school of design and arts - room a802
# yamaha music school
# upper madison college
# tdsb head office
# toronto district school board
# toronto catholic district school board
# st. andrew's junior high school
# eitz chaim day schools - administrative/patricia branch
# toronto international college
# metamorphosis greek orthodox school
# willow wood school
# royal canadian college of massage therapy
# stanford college
# citi college of canadian careers
# canada christian college
# institute of holistic nutrition
# the village @ york university
# school of photography
# beverley heights middle school
# beverley heights middle school
# st. augustine elementary school
# monsignor fraser college
# notre dame highschool
# robetech institute
# centennial college - story arts centre
# centennial college
# centennial college, centre for creative communications (ccc) library
# centennial college - story arts centre
# centennial college
# centennial college, centre for creative communications (ccc) library
# the hamilton institute for recreational studies
# off centre dj school
# canadian school of lutherie
# glendon campus, york university
# bedford park public school
# king george international college
# john fisher public school
# western town college
# king george international business college
# tamwood international collage toronto (tanwood international college toronto)
# john ross robertson public school
# john fisher public school
# king george international college
# king george international business college
# western town college
# university of bahcesehir campus toronto
# tamwood international collage toronto (tanwood international college toronto)
# london school of business and finance (lsbf)
# toronto school of thai massage
# deer park public school
# english school of canada
# deer park public school
# the bishop strachan school
# english school of canada
# upper canada college
# trios college
# trios college
# international institute of travel
# jarvis collegiate institute
# canadian national ballet school
# ilac high advanced, university level building
# st. michael's college
# university at st. michael's college
# university at st. michael's college
# victoria college
# martin prosperity institute
# loretto college
# ryerson university
# international institute of travel
# st josephs college secondary school
# st josephs college secondary school
# emmanuel college
# ryerson university department of architectural science
# marvel beauty school
# banting institute
# ryerson school of journalism at rogers communication- centre
# cdi college toronto
# university of toronto students' union
# ryerson university digital media experience lab
# chang school for continuing education (ced)
# best institute
# theatre school
# george brown yorkville school of makeup and esthetics
# ryerson school of fashion
# connect school of language
# ryerson university library
# victoria college quad
# ryerson school of image arts
# neill-wycik college-hotel
# ryerson university quad
# canadian national ballet school
# ryerson university campus store
# george brown college - sjg building
# george brown college - school of esl
# george brown college - school of esl
# college of sports media
# george brown college centre for hospitality and culinary arts
# george brown college st. james campus (c: centre for business)
# centre for business at george brown college
# st. micheal catholic school
# institute without boundaries
# george brown college continuing ed
# george brown college st. james campus
# george brown college (st. james campus) information and student services
# george brown school of design
# george brown school of design
# harris institute for the arts
# maclab at harris institute
# george brown school of design
# george brown college gym
# toronto film school
# ryerson university
# ryerson school of interior design
# ryerson university department of architectural science
# ted rogers school of retail management
# ted rogers school of management
# ryerson school of journalism at rogers communication- centre
# martin prosperity institute
# international institute of travel
# ryerson university digital media experience lab
# george brown college st. james campus (c: centre for business)
# george brown college centre for hospitality and culinary arts
# dorothy h. hoover library - ocad university
# 505 university ave.
# centre for business at george brown college
# the michener institute
# sgic - saint george international college
# banting institute
# chang school for continuing education (ced)
# institute without boundaries
# ryerson university human resources
# ryerson school of fashion
# ryerson school of image arts
# ryerson university library
# theatre school
# george brown college st. james campus
# ryerson university quad
# neill-wycik college-hotel
# greystone college
# george brown school of design
# best institute
# maclab at harris institute
# ocad university, annex building
# university of toronto dentistry
# canadian national ballet school
# ryerson university campus store
# george brown college gym
# toronto film school
# ryerson school of interior design
# george brown college st. james campus (c: centre for business)
# george brown college centre for hospitality and culinary arts
# centre for business at george brown college
# ryerson university
# college of sports media
# schulich school of business nadal management centre
# institute without boundaries
# ted rogers school of retail management
# ted rogers school of management
# george brown college - school of esl
# george brown college - school of esl
# george brown college - sjg building
# ryerson university department of architectural science
# ryerson school of journalism at rogers communication- centre
# george brown college st. james campus
# george brown college (st. james campus) information and student services
# tri-mentoring program office
# sgic - saint george international college
# ryerson university digital media experience lab
# ryerson university human resources
# chang school for continuing education (ced)
# george brown school of design
# maclab at harris institute
# ryerson school of image arts
# george brown school of design
# george brown school of design
# ryerson school of fashion
# ryerson university library
# ryerson university library 4th floor
# theatre school
# ryerson university quad
# george brown college gym
# ryerson university campus store
# st. micheal catholic school
# schulich school of business nadal management centre
# george brown college waterfront campus
# centre for business at george brown college
# college of sports media
# george brown college centre for hospitality and culinary arts
# george brown college st. james campus (c: centre for business)
# institute without boundaries
# kaplan international colleges
# george brown college st. james campus
# george brown college (st. james campus) information and student services
# george brown school of design
# george brown school of design
# george brown college gym
# ontario college of art and design university (ocadu)
# ontario college of art and design university (ocadu)
# dalla lana school of public health
# toronto film school
# martin prosperity institute
# ryerson university
# the michener institute
# 505 university ave.
# ryerson school of interior design
# banting institute
# ted rogers school of management
# ted rogers school of retail management
# university of toronto
# dorothy h. hoover library - ocad university
# university college
# university college
# university at st. michael's college
# university at st. michael's college
# ocad university tabletop
# st. michael's college
# cornerstone montessori prep school
# sgic - saint george international college
# ryerson university department of architectural science
# university of toronto - st. george campus
# knox college
# st josephs college secondary school
# st josephs college secondary school
# international institute of travel
# university of toronto engineering society
# ryerson university digital media experience lab
# university of toronto students' union
# ryerson university human resources
# chang school for continuing education (ced)
# greystone college
# school of graduate studies
# university of toronto dentistry
# ocad university, annex building
# ryerson university library
# theatre school
# ryerson school of image arts
# knox college chapel
# ontario college of art and design university (ocadu)
# ontario college of art and design university (ocadu)
# toronto film school
# schulich school of business nadal management centre
# dorothy h. hoover library - ocad university
# ryerson university
# ted rogers school of management
# ocad university tabletop
# ryerson school of interior design
# ted rogers school of retail management
# the michener institute
# ogden junior public school
# 505 university ave.
# ousa home office
# sgic - saint george international college
# cornerstone montessori prep school
# ryerson university digital media experience lab
# ryerson university human resources
# chang school for continuing education (ced)
# greystone college
# ocad university, annex building
# ryerson university library
# ryerson school of image arts
# ryerson school of fashion
# university of toronto dentistry
# university settlement recreation centre
# ryerson university campus store
# schulich school of business nadal management centre
# kaplan international colleges
# ontario college of art and design university (ocadu)
# ontario college of art and design university (ocadu)
# toronto film school
# schulich school of business nadal management centre
# kaplan international colleges
# ted rogers school of management
# dorothy h. hoover library - ocad university
# ted rogers school of retail management
# sgic - saint george international college
# ocad university marketing & communications office
# ocad university marketing & communications office
# george brown college (st. james campus) information and student services
# ryerson university human resources
# ocad university, annex building
# greystone college
# university settlement recreation centre
# george brown college gym
# toronto film school
# schulich school of business nadal management centre
# ted rogers school of management
# centre for business at george brown college
# ted rogers school of retail management
# george brown college centre for hospitality and culinary arts
# george brown college st. james campus (c: centre for business)
# college of sports media
# dorothy h. hoover library - ocad university
# institute without boundaries
# sgic - saint george international college
# ocad university marketing & communications office
# ocad university marketing & communications office
# george brown college st. james campus
# george brown college (st. james campus) information and student services
# ryerson university human resources
# george brown school of design
# greystone college
# george brown college gym
# charles xavier's school for gifted youth
# bialik hebrew day school
# a fictional hugh school
# forest hill public school
# the bishop strachan school
# upper canada college
# george brown college
# oise university of toronto
# ontario institute for studies in education
# woodsworth college
# claude t. bissell building, faculty of information (ischool)
# sutherland-chan school
# tartu college
# innis college residence
# dalla lana school of public health
# university college
# university college
# university of toronto
# trinity college
# rotman school of management
# knox college
# university of toronto - st. george campus
# massey college
# claude t. bissell building, faculty of information (ischool)
# victoria college
# university at st. michael's college
# university at st. michael's college
# oise university of toronto
# st. michael's college
# martin prosperity institute
# ontario institute for studies in education
# emmanuel college
# university of toronto students' union
# king edward junior and senior public school
# university of toronto engineering society
# loretto college
# cornerstone montessori prep school
# st josephs college secondary school
# st josephs college secondary school
# school of graduate studies
# banting institute
# munk school of global affairs
# knox college chapel
# wilson hall, new college
# wetmore hall, new college
# ontario college of art and design university (ocadu)
# ontario college of art and design university (ocadu)
# dalla lana school of public health
# central michigan university
# ogden junior public school
# braemar college
# westside montessori school
# ousa home office
# cornerstone montessori prep school
# ocad university tabletop
# the michener institute
# dorothy h. hoover library - ocad university
# toronto school of art (tsa)
# king edward junior and senior public school
# knox college
# 505 university ave.
# university of toronto engineering society
# toronto institute of bartending
# ocad university, annex building
# samuel lunenfield research institute
# knox college chapel
# wilson hall, new college
# new college quad
# university of toronto dentistry
# new college summer residence
# wetmore hall, new college
# fields institute
# university settlement recreation centre
# new college dining hall
# the waterfront school
# schulich school of business nadal management centre
# st. micheal catholic school
# centre for business at george brown college
# george brown college centre for hospitality and culinary arts
# college of sports media
# george brown college st. james campus (c: centre for business)
# george brown college waterfront campus
# george brown college - school of esl
# george brown college - school of esl
# george brown college - sjg building
# institute without boundaries
# kaplan international colleges
# george brown college st. james campus
# george brown college (st. james campus) information and student services
# george brown college continuing ed
# george brown school of design
# maclab at harris institute
# harris institute for the arts
# george brown school of design
# george brown school of design
# george brown college gym
# ontario college of art and design university (ocadu)
# ontario college of art and design university (ocadu)
# toronto film school
# schulich school of business nadal management centre
# ted rogers school of management
# dorothy h. hoover library - ocad university
# ted rogers school of retail management
# ocad university tabletop
# kaplan international colleges
# 505 university ave.
# sgic - saint george international college
# ocad university marketing & communications office
# ocad university marketing & communications office
# ryerson university digital media experience lab
# ryerson university human resources
# george brown college (st. james campus) information and student services
# greystone college
# ocad university, annex building
# university settlement recreation centre
# george brown college gym
# bryan college
# bluenotes' head office
# fieldstone day school
# medix college - toronto
# cedarvale public school
# united synagogue day school
# york university glendon campus
# bonnie gordon college of confectionary arts
# st. luke's catholic school
# old orchard school
# alexander muir elementary school
# toronto institute for the enjoyment of music
# holy family catholic school
# silverthorn community school
# great lakes college
# indian road crescent public school
# kikkawa college
# trebas institute
# oxford school of learning
# dalla lana school of public health
# toronto film school
# university at st. michael's college
# university at st. michael's college
# university of toronto
# st. michael's college
# university college
# university college
# victoria college
# trinity college
# st josephs college secondary school
# st josephs college secondary school
# banting institute
# university of toronto - st. george campus
# loretto college
# ryerson university
# emmanuel college
# knox college
# the michener institute
# rotman school of management
# massey college
# 505 university ave.
# university of toronto students' union
# ted rogers school of retail management
# ted rogers school of management
# ontario institute for studies in education
# dorothy h. hoover library - ocad university
# ryerson university department of architectural science
# oise university of toronto
# claude t. bissell building, faculty of information (ischool)
# sgic - saint george international college
# school of graduate studies
# munk school of global affairs
# ryerson university digital media experience lab
# ryerson university human resources
# chang school for continuing education (ced)
# biztech institute
# abdul hamid khan law office
# leslieville junior public school
# toronto police college
# st. theresa school
# canadian institute of floral design
# liaison college
# christ the king school
# sunnylea junior school
# pizza pizza university
# humber college - erp
# weston collegiate institute
# st. eugene separate school
# transfiguration catholic school
# canadian college of business etobicoke
# humber college community employment services

# %%
nearbyCollege_University1 = nearbyCollege_University[nearbyCollege_University['Venue'].isin(uni_venues)]

# %%
nearbyCollege_University1.head()
# Out:
#                           Neighbourhood  Neighbourhood Latitude  \
# 0                         Rouge,Malvern               43.806686
# 2  Highland Creek,Rouge Hill,Port Union               43.784535
# 5                             Cedarbrae               43.773136
# 8                             Cedarbrae               43.773136
# 9                             Cedarbrae               43.773136
#
#    Neighbourhood Longitude                                              Venue  \
# 0               -79.194353                                  Evergreen College
# 2               -79.160497                         st brendan catholic school
# 5               -79.239476                        St. Richard Catholic School
# 8               -79.239476                                     Oxford College
# 9               -79.239476  UWIN Pro O/A the Canadian College for Higher S...
#
#    Venue Latitude  Venue Longitude
# 0       43.802162       -79.199654
# 2       43.783052       -79.149267
# 5       43.768646       -79.240365
# 8       43.777108       -79.250061
# 9       43.776911       -79.246111

# %% [markdown]
# __Shopping malls and shopping plazas__ can attract visitors and citizens, who are potential cunsumers of bubble tea.

# %%
nearby_shopping_plaza = getNearbyvenues(toronto_data['Neighbourhood'],
                                  toronto_data['Latitude'],
                                  toronto_data['Longitude'],Shopping_Plaza,radius = 1000,LIMIT = 100)

# %%
nearby_shopping_plaza.head()
# Out:
#                                        Neighbourhood  Neighbourhood Latitude  \
# 0                    Guildwood,Morningside,West Hill               43.763573
# 1  Dorset Park,Scarborough Town Centre,Wexford He...               43.757410
# 2              Clarks Corners,Sullivan,Tam O'Shanter               43.781638
# 3  Agincourt North,L'Amoreaux East,Milliken,Steel...               43.815252
# 4  Agincourt North,L'Amoreaux East,Milliken,Steel...               43.815252
#
#    Neighbourhood Longitude                   Venue  Venue Latitude  \
# 0               -79.188711          Westhill Plaza       43.768039
# 1               -79.273304  Midland Lawrence Plaza       43.756688
# 2               -79.304302            Warden Plaza       43.785275
# 3               -79.284577          Midland Square       43.818752
# 4               -79.284577                Maxim ii       43.814862
#
#    Venue Longitude
# 0       -79.189845
# 1       -79.265784
# 2       -79.310410
# 3       -79.290249
# 4       -79.293021

# %%
nearby_shopping_mall =getNearbyvenues(toronto_data['Neighbourhood'],
                                  toronto_data['Latitude'],
                                  toronto_data['Longitude'],Shopping_Mall,radius = 1000,LIMIT = 100)

# %%
nearby_shopping_mall.head()
# Out:
#                                Neighbourhood  Neighbourhood Latitude  \
# 0                              Rouge,Malvern               43.806686
# 1            Guildwood,Morningside,West Hill               43.763573
# 2            Guildwood,Morningside,West Hill               43.763573
# 3  East Birchmount Park,Ionview,Kennedy Park               43.727929
# 4                           Maryvale,Wexford               43.750071
#
#    Neighbourhood Longitude                  Venue  Venue Latitude  \
# 0               -79.194353        Pleasant Corner       43.801164
# 1               -79.188711        Kingston Square       43.769860
# 2               -79.188711   Morningside Crossing       43.770599
# 3               -79.262029          Midland Plaza       43.734730
# 4               -79.295849  Wexford Heights Plaza       43.746136
#
#    Venue Longitude
# 0       -79.200254
# 1       -79.187158
# 2       -79.185541
# 3       -79.259544
# 4       -79.293782

# %%
nearby_shopping = pd.concat([nearby_shopping_plaza,nearby_shopping_mall],axis = 0)

# %% [markdown]
# __Let's create an interactive map with all the neighbourhoods, collected boba shops, schools, shopping malls and shopping plazas in Toronto in different color.The density of boba shops is express via headmap. By clicking on different buttons on the control board, we can explore the correlation between different types (boba shops, schools, shopping malls and shopping plazas)of venues, in order to try to discover useful information.__

# %%
# create map
lgd_txt = '<span style="color: {col};">{txt}</span>'
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
fgn = folium.FeatureGroup(name= lgd_txt.format( txt= 'neighborhoods',col='blue'))
fgs = folium.FeatureGroup(name= lgd_txt.format( txt= 'schools',col='green'))
fgsp = folium.FeatureGroup(name= lgd_txt.format( txt= 'shopping malls',col='orange'))
fgbb = folium.FeatureGroup(name= lgd_txt.format( txt= 'boba frontstores heatmap',col='red'))
# add markers to the map
for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgn) 
map_Toronto.add_child(fgn)
for lat, lng, label in zip(nearbyCollege_University1['Venue Latitude'], nearbyCollege_University1['Venue Longitude'], nearbyCollege_University1['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgs)
map_Toronto.add_child(fgs)

for lat, lng, label in zip(nearby_shopping['Venue Latitude'], nearby_shopping['Venue Longitude'], nearby_shopping['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='orange',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgsp)
map_Toronto.add_child(fgsp)
HeatMap(nearbybobashop[['Venue Latitude','Venue Longitude']],radius=25, blur=10).add_to(fgbb)
map_Toronto.add_child(fgbb)
folium.map.LayerControl('bottomright', collapsed= False).add_to(map_Toronto)
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we have all the boba shops,school venues, shopping venues in neighbourhoods within Toronto, and we can roughly estimate the number of boba shops in boroughs: Old Toronto and North York have the highest one, while Scarborough, East York,Mississauga and Etobicoke have not been "invaded" by a large number of boba shops.

# %% [markdown]
# We're now ready to concatenate these data for analysis to produce the report on optimal locations for a new boba frontstore.

# %%
neighborhoodslist = toronto_data[['Neighbourhood','Latitude','Longitude']]

# %%
neighborhoodslist.set_index('Neighbourhood',inplace = True)

# %%
neighborhoodslist.head(1)
# Out:
#                 Latitude  Longitude
# Neighbourhood
# Rouge,Malvern  43.806686 -79.194353

# %%
neighborhoodslist1 = pd.merge(neighborhoodslist, pd.DataFrame(nearbybobashop.groupby('Neighbourhood').count()['Venue']), how='outer',left_index=True, right_index=True)
neighborhoodslist1.rename(columns={'Venue':'bobashop'}, inplace=True)

# %%
neighborhoodslist1.head()
# Out:
#                                                      Latitude  Longitude  \
# Neighbourhood
# Adelaide,King,Richmond                              43.650571 -79.384568
# Agincourt                                           43.794200 -79.262029
# Agincourt North,L'Amoreaux East,Milliken,Steele...  43.815252 -79.284577
# Albion Gardens,Beaumond Heights,Humbergate,Jame...  43.739416 -79.588437
# Alderwood,Long Branch                               43.602414 -79.543484
#
#                                                     bobashop
# Neighbourhood
# Adelaide,King,Richmond                                  27.0
# Agincourt                                                2.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...       2.0
# Albion Gardens,Beaumond Heights,Humbergate,Jame...       1.0
# Alderwood,Long Branch                                    NaN

# %%
neighborhoodslist2 = pd.merge(neighborhoodslist1, pd.DataFrame(nearbyCollege_University1.groupby('Neighbourhood').count()['Venue']), how='outer',left_index=True, right_index=True)
neighborhoodslist2.rename(columns={'Venue':'school'}, inplace=True)

# %%
neighborhoodslist3 = pd.merge(neighborhoodslist2, pd.DataFrame(nearby_shopping.groupby('Neighbourhood').count()['Venue']), how='outer',left_index=True, right_index=True)
neighborhoodslist3.rename(columns={'Venue':'shopping'}, inplace=True)

# %%
neighborhoodslist3.fillna(0,inplace = True)

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# The goal of this project is to provide a list of promising neighbourhoods for new boba storefronts.These neighbourhoods should satisfy the primary criterium of low density of boba shops. Then we give preference to neighbourhoods with as many as possible number of schools and shopping venues.
#
# To clearly define the scope of searching area, we will only take into consideration venues in radius of 1000 meters about the given coordinate of neighbourhoods.
#
# Above we have collected the required **data: coordinate of each neighbourhood in Toronto, location and number of boba shops in each neighbourhood, location and number of school venues in each neighbourhood, location and number of shopping venues in each neighbourhood within 1km from neighbourhood center**.
#
# In the next step, we will use machine learning methods to create clusters and try to find out ones that meet up with the expectation of promising candidates.After machine learning, we will also filter promising neighbourhoods that have no more than 5 boba shops and more than 3 school venues.
#
# In the final part, we will focus on visualizing the machine learning result and filter result on map.We will present all possible neighbourhoods for new boba stores on map, to offer a 'neighbourhood level' reconmendation to a specific boba brands.

# %% [markdown]
# #### Try to use machine learning method k-means

# %%
neighborhoodslist3 = neighborhoodslist3.reset_index()
# set number of clusters
kclusters = 4

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(neighborhoodslist3[['bobashop','school','shopping']])

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1, 1, 1, 1, 1, 1, 1, 3, 1])

# %%
# add clustering labels
neighborhoodslist3.insert(0, 'Cluster Labels', kmeans.labels_)

# %% [markdown]
# Manually select promising neighbourhoods with the requirement of no more than 5 boba shops and more than 3 scools.

# %%
neighborhoodslist3.head()
# Out:
#    Cluster Labels                                      Neighbourhood  \
# 0               0                             Adelaide,King,Richmond
# 1               1                                          Agincourt
# 2               1  Agincourt North,L'Amoreaux East,Milliken,Steel...
# 3               1  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 4               1                              Alderwood,Long Branch
#
#     Latitude  Longitude  bobashop  school  shopping
# 0  43.650571 -79.384568      27.0    26.0      20.0
# 1  43.794200 -79.262029       2.0     5.0       5.0
# 2  43.815252 -79.284577       2.0     1.0       5.0
# 3  43.739416 -79.588437       1.0     2.0       1.0
# 4  43.602414 -79.543484       0.0     1.0       2.0

# %%
prolist = neighborhoodslist3[(neighborhoodslist3['bobashop']<6)&(neighborhoodslist3['school']>3)].sort_values(by=['school','shopping'],ascending = False)

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data. First let's have a closer look to each cluster we got from k-means:

# %% [markdown]
# There are 7 neighbourhoods in cluster0, and the number of bobashops, schools, and shopping venues are close.

# %%
neighborhoodslist3[neighborhoodslist3['Cluster Labels'] == 0].reset_index()
# Out:
#    index  Cluster Labels                            Neighbourhood   Latitude  \
# 0      0               0                   Adelaide,King,Richmond  43.650571
# 1     20               0  Chinatown,Grange Park,Kensington Market  43.653206
# 2     22               0                     Church and Wellesley  43.665860
# 3     27               0            Commerce Court,Victoria Hotel  43.648198
# 4     32               0  Design Exchange,Toronto Dominion Centre  43.647177
# 5     44               0    First Canadian Place,Underground city  43.648429
# 6     83               0                           St. James Town  43.651494
#
#    Longitude  bobashop  school  shopping
# 0 -79.384568      27.0    26.0      20.0
# 1 -79.400049      19.0    28.0       7.0
# 2 -79.383160      24.0    30.0      10.0
# 3 -79.379817      19.0    18.0      18.0
# 4 -79.381576      16.0    15.0      18.0
# 5 -79.382280      21.0    18.0      20.0
# 6 -79.375418      17.0    34.0      16.0

# %% [markdown]
# There are 88 neighbourhoods in cluster1, the biggest cluster. Most of them far from schools and shopping areas. This cluster supports the assumption that low density of schools and shopping hinders the development of boba market.

# %%
neighborhoodslist3[neighborhoodslist3['Cluster Labels'] == 1].reset_index()
# Out:
#     index  Cluster Labels                                      Neighbourhood  \
# 0       1               1                                          Agincourt
# 1       2               1  Agincourt North,L'Amoreaux East,Milliken,Steel...
# 2       3               1  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 3       4               1                              Alderwood,Long Branch
# 4       5               1      Bathurst Manor,Downsview North,Wilson Heights
# 5       6               1                                    Bayview Village
# 6       7               1                   Bedford Park,Lawrence Manor East
# 7       9               1                         Birch Cliff,Cliffside West
# 8      10               1  Bloordale Gardens,Eringate,Markland Wood,Old B...
# 9      11               1         Brockton,Exhibition Place,Parkdale Village
# 10     12               1  Business Reply Mail Processing Centre 969 Eastern
# 11     13               1                         CFB Toronto,Downsview East
# 12     14               1  CN Tower,Bathurst Quay,Island airport,Harbourf...
# 13     15               1                         Cabbagetown,St. James Town
# 14     16               1                                Caledonia-Fairbanks
# 15     17               1              Canada Post Gateway Processing Centre
# 16     18               1                                          Cedarbrae
# 17     21               1                                           Christie
# 18     23               1                      Clairlea,Golden Mile,Oakridge
# 19     24               1              Clarks Corners,Sullivan,Tam O'Shanter
# 20     25               1      Cliffcrest,Cliffside,Scarborough Village West
# 21     26               1  Cloverdale,Islington,Martin Grove,Princess Gar...
# 22     28               1                                         Davisville
# 23     29               1                                   Davisville North
# 24     30               1  Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 25     31               1        Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 26     33               1                                    Don Mills North
# 27     34               1  Dorset Park,Scarborough Town Centre,Wexford He...
# 28     35               1                        Dovercourt Village,Dufferin
# 29     36               1                                  Downsview Central
# ..    ...             ...                                                ...
# 59     69               1                             Newtonbrook,Willowdale
# 60     70               1                                 North Toronto West
# 61     71               1                                          Northwest
# 62     72               1                     Northwood Park,York University
# 63     73               1                              Parkdale,Roncesvalles
# 64     74               1                                          Parkwoods
# 65     76               1                                           Rosedale
# 66     77               1                                           Roselawn
# 67     78               1                                      Rouge,Malvern
# 68     79               1                                  Runnymede,Swansea
# 69     81               1                                Scarborough Village
# 70     82               1                            Silver Hills,York Mills
# 71     85               1                                    Studio District
# 72     86               1                  The Annex,North Midtown,Yorkville
# 73     87               1                                        The Beaches
# 74     88               1                      The Beaches West,India Bazaar
# 75     89               1                        The Danforth West,Riverdale
# 76     90               1                       The Junction North,Runnymede
# 77     91               1        The Kingsway,Montgomery Road,Old Mill North
# 78     92               1                                   Thorncliffe Park
# 79     93               1                                        Upper Rouge
# 80     94               1                                   Victoria Village
# 81     95               1                                          Westmount
# 82     96               1                                             Weston
# 83     97               1                                   Willowdale South
# 84     98               1                                    Willowdale West
# 85     99               1                                             Woburn
# 86    100               1                     Woodbine Gardens,Parkview Hill
# 87    101               1                                   Woodbine Heights
# 88    102               1                                    York Mills West
#
#      Latitude  Longitude  bobashop  school  shopping
# 0   43.794200 -79.262029       2.0     5.0       5.0
# 1   43.815252 -79.284577       2.0     1.0       5.0
# 2   43.739416 -79.588437       1.0     2.0       1.0
# 3   43.602414 -79.543484       0.0     1.0       2.0
# 4   43.754328 -79.442259       0.0     0.0       1.0
# 5   43.786947 -79.385975       0.0     0.0       2.0
# 6   43.733283 -79.419750       0.0     0.0       0.0
# 7   43.692657 -79.264848       0.0     1.0       0.0
# 8   43.643515 -79.577201       0.0     1.0       2.0
# 9   43.636847 -79.428191       2.0     1.0       3.0
# 10  43.662744 -79.321558       1.0     1.0       1.0
# 11  43.737473 -79.464763       0.0     1.0       0.0
# 12  43.628947 -79.394420       0.0     1.0       0.0
# 13  43.667967 -79.367675       0.0     4.0       1.0
# 14  43.689026 -79.453512       0.0     0.0       1.0
# 15  43.636966 -79.615819       3.0     2.0       2.0
# 16  43.773136 -79.239476       0.0     3.0       0.0
# 17  43.669542 -79.422564       7.0     0.0       1.0
# 18  43.711112 -79.284577       0.0     1.0       0.0
# 19  43.781638 -79.304302       0.0     1.0       3.0
# 20  43.716316 -79.239476       0.0     0.0       0.0
# 21  43.650943 -79.554724       0.0     0.0       2.0
# 22  43.704324 -79.388790       4.0     7.0       3.0
# 23  43.712751 -79.390197       4.0     5.0       3.0
# 24  43.686412 -79.400049       0.0     4.0       4.0
# 25  43.691116 -79.476013       0.0     1.0       2.0
# 26  43.745906 -79.352188       0.0     5.0       0.0
# 27  43.757410 -79.273304       0.0     0.0       1.0
# 28  43.669005 -79.442259       1.0     0.0       1.0
# 29  43.728496 -79.495697       0.0     1.0       0.0
# ..        ...        ...       ...     ...       ...
# 59  43.789053 -79.408493       2.0     3.0       2.0
# 60  43.715383 -79.405678       2.0     2.0       0.0
# 61  43.706748 -79.594054       0.0     0.0       0.0
# 62  43.767980 -79.487262       0.0     1.0       0.0
# 63  43.648960 -79.456325       0.0     2.0       2.0
# 64  43.753259 -79.329656       0.0     1.0       2.0
# 65  43.679563 -79.377529       0.0     1.0       2.0
# 66  43.711695 -79.416936       0.0     3.0       1.0
# 67  43.806686 -79.194353       0.0     1.0       1.0
# 68  43.651571 -79.484450       2.0     1.0       0.0
# 69  43.744734 -79.239476       0.0     1.0       0.0
# 70  43.757490 -79.374714       0.0     1.0       0.0
# 71  43.659526 -79.340923       1.0     1.0       0.0
# 72  43.672710 -79.405678       4.0     8.0       2.0
# 73  43.676357 -79.293031       1.0     1.0       1.0
# 74  43.668999 -79.315572       1.0     2.0       2.0
# 75  43.679557 -79.352188       2.0     3.0       1.0
# 76  43.673185 -79.487262       0.0     0.0       0.0
# 77  43.653654 -79.506944       0.0     0.0       0.0
# 78  43.705369 -79.349372       1.0     0.0       5.0
# 79  43.836125 -79.205636       0.0     0.0       0.0
# 80  43.725882 -79.315572       0.0     0.0       0.0
# 81  43.696319 -79.532242       0.0     1.0       0.0
# 82  43.706876 -79.518188       0.0     1.0       0.0
# 83  43.770120 -79.408493      16.0     5.0       4.0
# 84  43.782736 -79.442259       0.0     1.0       0.0
# 85  43.770992 -79.216917       0.0     0.0       0.0
# 86  43.706397 -79.309937       0.0     0.0       0.0
# 87  43.695344 -79.318389       0.0     0.0       0.0
# 88  43.752758 -79.400049       1.0     1.0       0.0
#
# [89 rows x 8 columns]

# %% [markdown]
# Having 3 neighbourhoods, cluster2 shows a distinguishing feature of extremely high number of bobashops, although there are also a large number of schools and shopping places.

# %%
neighborhoodslist3[neighborhoodslist3['Cluster Labels'] == 2]
# Out:
#     Cluster Labels            Neighbourhood   Latitude  Longitude  bobashop  \
# 19               2       Central Bay Street  43.657952 -79.387383      45.0
# 75               2             Queen's Park  43.662301 -79.389494      35.0
# 80               2  Ryerson,Garden District  43.657162 -79.378937      28.0
#
#     school  shopping
# 19    37.0      16.0
# 75    33.0      10.0
# 80    37.0      16.0

# %% [markdown]
# The 4 neighbourhoods in Cluster3 have less number of bobashops than cluster0 and cluster2, but higher number of schools and shopping places than cluster1.

# %%
neighborhoodslist3[neighborhoodslist3['Cluster Labels'] == 3].reset_index(drop=True)
# Out:
#    Cluster Labels                    Neighbourhood   Latitude  Longitude  \
# 0               3                      Berczy Park  43.644771 -79.373306
# 1               3    Harbord,University of Toronto  43.662696 -79.400049
# 2               3         Harbourfront,Regent Park  43.654260 -79.360636
# 3               3  Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
#
#    bobashop  school  shopping
# 0       2.0    14.0       6.0
# 1       8.0    28.0       2.0
# 2       1.0    17.0       1.0
# 3       5.0    20.0      11.0

# %% [markdown]
# __After scrolling down the 4 clusters, we can regard cluster3 as the cluster that reaches the criterium of promising starting points for the next boba frontstore.__
# Now we can visualize __the resulting clusters on Toronto map__ and show the __promising neighbourhoods in cluster3 on heatmap of boba shops__.

# %%
neighborhoodslist3.groupby('Cluster Labels').mean()
# Out:
#                  Latitude  Longitude   bobashop     school   shopping
# Cluster Labels
# 0               43.652134 -79.383838  20.428571  24.142857  15.571429
# 1               43.712630 -79.399497   0.808989   1.550562   1.370787
# 2               43.659139 -79.385271  36.000000  35.666667  14.000000
# 3               43.652040 -79.377209   4.000000  19.750000   5.000000

# %%
neighborhoodslist3.reset_index(inplace = True)

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(neighborhoodslist3['Latitude'], neighborhoodslist3['Longitude'], neighborhoodslist3['Neighbourhood'], neighborhoodslist3['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
proneis = neighborhoodslist3[neighborhoodslist3['Cluster Labels'] == 3]
# create map
# create map
lgd_txt = '<span style="color: {col};">{txt}</span>'
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
fgn = folium.FeatureGroup(name= lgd_txt.format( txt= 'neighborhoods',col='blue'))
fgs = folium.FeatureGroup(name= lgd_txt.format( txt= 'schools',col='green'))
fgsp = folium.FeatureGroup(name= lgd_txt.format( txt= 'shopping malls',col='orange'))
fgbb = folium.FeatureGroup(name= lgd_txt.format( txt= 'boba frontstores heatmap',col='red'))
# add markers to the map
for lat, lng, label in zip(proneis['Latitude'], proneis['Longitude'], proneis['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgn) 
map_Toronto.add_child(fgn)
for lat, lng, label in zip(nearbyCollege_University1['Venue Latitude'], nearbyCollege_University1['Venue Longitude'], nearbyCollege_University1['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgs)
map_Toronto.add_child(fgs)

for lat, lng, label in zip(nearby_shopping['Venue Latitude'], nearby_shopping['Venue Longitude'], nearby_shopping['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='orange',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgsp)
map_Toronto.add_child(fgsp)
HeatMap(nearbybobashop[['Venue Latitude','Venue Longitude']],radius=25, blur=10).add_to(fgbb)
map_Toronto.add_child(fgbb)
folium.map.LayerControl('bottomright', collapsed= False).add_to(map_Toronto)
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's look at the manually selected neighbourhoods.

# %%
# create map
lgd_txt = '<span style="color: {col};">{txt}</span>'
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
fgn = folium.FeatureGroup(name= lgd_txt.format( txt= 'promising neighborhoods',col='blue'))
fgs = folium.FeatureGroup(name= lgd_txt.format( txt= 'schools',col='green'))
fgsp = folium.FeatureGroup(name= lgd_txt.format( txt= 'shopping malls',col='orange'))
fgbb = folium.FeatureGroup(name= lgd_txt.format( txt= 'boba frontstores heatmap',col='red'))
# add markers to the map
for lat, lng, label in zip(prolist['Latitude'], prolist['Longitude'], prolist['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgn) 
map_Toronto.add_child(fgn)
for lat, lng, label in zip(nearbyCollege_University1['Venue Latitude'], nearbyCollege_University1['Venue Longitude'], nearbyCollege_University1['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgs)
map_Toronto.add_child(fgs)

for lat, lng, label in zip(nearby_shopping['Venue Latitude'], nearby_shopping['Venue Longitude'], nearby_shopping['Venue']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='orange',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(fgsp)
map_Toronto.add_child(fgsp)
HeatMap(nearbybobashop[['Venue Latitude','Venue Longitude']],radius=25, blur=10).add_to(fgbb)
map_Toronto.add_child(fgbb)
folium.map.LayerControl('bottomright', collapsed= False).add_to(map_Toronto)
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Check the same neighbourhoods in both clusters3 and manual selection.

# %%
prolist.reset_index(drop=True)
# Out:
#     Cluster Labels                                      Neighbourhood  \
# 0                3                    Stn A PO Boxes 25 The Esplanade
# 1                3                           Harbourfront,Regent Park
# 2                3                                        Berczy Park
# 3                1                  The Annex,North Midtown,Yorkville
# 4                1                                         Davisville
# 5                1                                          Agincourt
# 6                1                                   Davisville North
# 7                1                                    Don Mills North
# 8                1  Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 9                1                            Little Portugal,Trinity
# 10               1                         Cabbagetown,St. James Town
# 11               1         Humber Bay Shores,Mimico South,New Toronto
# 12               1                                 Humewood-Cedarvale
#
#      Latitude  Longitude  bobashop  school  shopping
# 0   43.646435 -79.374846       5.0    20.0      11.0
# 1   43.654260 -79.360636       1.0    17.0       1.0
# 2   43.644771 -79.373306       2.0    14.0       6.0
# 3   43.672710 -79.405678       4.0     8.0       2.0
# 4   43.704324 -79.388790       4.0     7.0       3.0
# 5   43.794200 -79.262029       2.0     5.0       5.0
# 6   43.712751 -79.390197       4.0     5.0       3.0
# 7   43.745906 -79.352188       0.0     5.0       0.0
# 8   43.686412 -79.400049       0.0     4.0       4.0
# 9   43.647927 -79.419750       0.0     4.0       3.0
# 10  43.667967 -79.367675       0.0     4.0       1.0
# 11  43.605647 -79.501321       0.0     4.0       0.0
# 12  43.693781 -79.428191       0.0     4.0       0.0

# %%
proneis.set_index('Neighbourhood')
# Out:
#                                  Cluster Labels   Latitude  Longitude  \
# Neighbourhood
# Berczy Park                                   3  43.644771 -79.373306
# Harbord,University of Toronto                 3  43.662696 -79.400049
# Harbourfront,Regent Park                      3  43.654260 -79.360636
# Stn A PO Boxes 25 The Esplanade               3  43.646435 -79.374846
#
#                                  bobashop  school  shopping
# Neighbourhood
# Berczy Park                           2.0    14.0       6.0
# Harbord,University of Toronto         8.0    28.0       2.0
# Harbourfront,Regent Park              1.0    17.0       1.0
# Stn A PO Boxes 25 The Esplanade       5.0    20.0      11.0

# %%
pd.merge(proneis.set_index('Neighbourhood'),prolist.set_index('Neighbourhood'),left_index=True, right_index=True)
# Out:
#                                  Cluster Labels_x  Latitude_x  Longitude_x  \
# Neighbourhood
# Berczy Park                                     3   43.644771   -79.373306
# Harbourfront,Regent Park                        3   43.654260   -79.360636
# Stn A PO Boxes 25 The Esplanade                 3   43.646435   -79.374846
#
#                                  bobashop_x  school_x  shopping_x  index  \
# Neighbourhood
# Berczy Park                             2.0      14.0         6.0      8
# Harbourfront,Regent Park                1.0      17.0         1.0     51
# Stn A PO Boxes 25 The Esplanade         5.0      20.0        11.0     84
#
#                                  Cluster Labels_y  Latitude_y  Longitude_y  \
# Neighbourhood
# Berczy Park                                     3   43.644771   -79.373306
# Harbourfront,Regent Park                        3   43.654260   -79.360636
# Stn A PO Boxes 25 The Esplanade                 3   43.646435   -79.374846
#
#                                  bobashop_y  school_y  shopping_y
# Neighbourhood
# Berczy Park                             2.0      14.0         6.0
# Harbourfront,Regent Park                1.0      17.0         1.0
# Stn A PO Boxes 25 The Esplanade         5.0      20.0        11.0

# %% [markdown]
# Berczy Park, Harbourfront,Regent Park, Stn A PO Boxes 25 The Esplanade are selected by both approaches, and they all situate in the south of old Toronto near the seashore.

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# Purpose of this project was to detect promising neighborhoods for new boba storefront, which have low density of bubble tea shops but high of schools and shopping malls. At the beginning, we explore all bubble tea shops, schools, shopping places within 1km from each neighbor center. By plotting a heatmap, we roughly know the distribution of boba shops in Toronto. To achieve the goal, we try two methods, one is k-means and the other is manual selection. There are 4 neighborhoods in k-means results but 13 in manual selection. The coincidence of 3 neighborhoods somewhat proofs the work of machine learning.
#
# Result of K-Means is a cluster including Berczy Park, Harbord, University of Toronto, Harbourfront, Regent Park, Stn A PO Boxes 25 The Esplanade. Result of manual selection is a cluster containing 13 neighborhoods. The common ones that they select are Berczy Park, Harbourfront, Regent Park, Stn A PO Boxes 25 The Esplanade. However, these results certainly do not imply these neighborhoods are ideal locations for a new boba storefront. Our goal in this analysis is detecting neighborhoods with as less as possible boba shops but as many as possible schools and shopping places within 1km.It is entirely possible that there is factors that stop boba brands from opening storefront in these neighborhoods, like low consumption level of people in the neighborhood, high rent, or stress of strong competitors. For further research, below the Top10 boba brands sorted by number of boba storefronts in Toronto is provided.

# %%
pd.DataFrame(nearbybobashop.groupby('Venue').count().sort_values(by='Neighbourhood',ascending = False)['Neighbourhood'][:10])
# Out:
#                         Neighbourhood
# Venue
# Real Fruit Bubble Tea              20
# Tea Shop 168                       15
# Sharetea                           12
# Chatime                            11
# Presotea                           10
# CoCo Fresh Tea & Juice              9
# Chatime Atealier                    9
# Chatime 日出茶太                        9
# The Alley                           9
# ZenQ                                8

# %%
pd.DataFrame(nearbybobashop.groupby('Venue').count().sort_values(by='Neighbourhood',ascending = False).index.values[:10]).rename(columns={0:'boba brand'})
# Out:
#                boba brand
# 0   Real Fruit Bubble Tea
# 1            Tea Shop 168
# 2                Sharetea
# 3                 Chatime
# 4                Presotea
# 5  CoCo Fresh Tea & Juice
# 6        Chatime Atealier
# 7            Chatime 日出茶太
# 8               The Alley
# 9                    ZenQ

# %% [markdown]
# Recommended neighbourhoods should therefore be considered only as a starting point for more detailed analysis which could eventually result in location which has not only no nearby competition but also other factors taken into account and all other relevant conditions met.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Final decision on optimal location will be made by stakeholders of boba shops based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location (traffic, parking, sightseeing attractions),residence composition, real estate availability, prices, social and economic dynamics of every neighborhood etc.
